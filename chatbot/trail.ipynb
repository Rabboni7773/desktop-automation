# %%
import json

# %%
with open("/home/rabboni/Desktop/desktop-automation/chatbot/prompts.json", "r") as f:
    prompts = json.load(f)
print(prompts["sys_prompts"]["chatbot_prompt"])
# Out:
# you are an expert chatbot answer human questions accordingly

# %%
from langgraph.checkpoint.sqlite import SqliteSaver
import sqlite3

# %%
conn = sqlite3.connect("trail.db", check_same_thread=False)

# %%
memory = SqliteSaver(conn = conn)

# %%
list(memory.list({"configurable" : {"thread_id" : "f81e20ef-24d2-44bf-b176-b1c6b3423533"}}))
# Out:
# []
